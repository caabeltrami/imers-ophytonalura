# %% [markdown]
# <a href="https://colab.research.google.com/github/caabeltrami/imers-ophytonalura/blob/main/Imers%C3%A3o_Phyton_Aula%2003.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Aula 2 - Importação**

# %%
import pandas as pd
import plotly.express as px

# %%
df_principal = pd.read_excel("/content/Imersão Python - Tabela de ações.xlsx", sheet_name="Principal")

# %%
df_principal.head(10)
# Out:
#    Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0  USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1  CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2  PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3  SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4  CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
# 5  PRIO3 2024-01-26        45.69          1.98           2.42         -0.78
# 6  PETR4 2024-01-26        39.96          1.73           6.47          7.30
# 7  VALE3 2024-01-26        69.50          1.66           2.06         -9.97
# 8  MULT3 2024-01-26        28.19          1.58           2.03         -0.81
# 9  ITUB4 2024-01-26        32.81          1.48          -0.39         -3.36
#
#    Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx  ... Variação Sem (R$)  \
# 0          2.26         15.97      9.18      9.56  ...      5.149330e+08
# 1        -12.11         50.56      6.66      6.86  ...      1.775160e+08
# 2          7.64         77.55     40.81     42.34  ...      7.165276e+09
# 3         -4.89         18.85     51.89     53.17  ...      7.576423e+08
# 4         -3.66         20.70     36.37     37.32  ...      1.692121e+08
# 5         -0.78          8.08     44.25     45.69  ...      8.636695e+08
# 6          7.30         95.01     38.91     40.09  ...      1.108870e+10
# 7         -9.97        -23.49     67.50     69.81  ...      5.887455e+09
# 8         -0.81         24.02     27.71     28.36  ...      1.505970e+08
# 9         -3.36         34.25     32.35     32.91  ...     -6.168127e+08
#
#    Resultado.1  Variação Mês (%)  Valor Inicial Mês (R$)  Variação Mês (R$)  \
# 0        Subiu            0.0226                9.290045       1.081515e+08
# 1        Subiu           -0.1211                7.759700      -1.043592e+09
# 2        Subiu            0.0764               38.981791       7.087773e+09
# 3        Subiu           -0.0489               55.630323      -1.859212e+09
# 4        Subiu           -0.0366               38.509446      -2.645988e+08
# 5        Subiu           -0.0078               46.049184      -2.873508e+08
# 6        Subiu            0.0730               37.241379       1.241443e+10
# 7        Subiu           -0.0997               77.196490      -3.230159e+10
# 8        Subiu           -0.0081               28.420204      -6.181093e+07
# 9       Desceu           -0.0336               33.950745      -5.477394e+09
#
#   Resultado.2 Variação 12M (%) Valor Inicial 12M (R$)  Variação 12M (R$)  \
# 0       Subiu           0.1597               8.191774       6.738901e+08
# 1      Desceu           0.5056               4.529756       2.543452e+09
# 2       Subiu           0.7755              23.632780       4.361654e+10
# 3      Desceu           0.1885              44.518300       5.735331e+09
# 4      Desceu           0.2070              30.737365       1.194474e+09
# 5      Desceu           0.0808              42.274241       2.732644e+09
# 6       Subiu           0.9501              20.491257       8.890296e+10
# 7      Desceu          -0.2349              90.837799      -8.955313e+10
# 8      Desceu           0.2402              22.730205       1.465985e+09
# 9      Desceu           0.3425              24.439479       4.019184e+10
#
#   Resultado.3
# 0       Subiu
# 1       Subiu
# 2       Subiu
# 3       Subiu
# 4       Subiu
# 5       Subiu
# 6       Subiu
# 7      Desceu
# 8       Subiu
# 9       Subiu
#
# [10 rows x 32 columns]

# %%
df_total_de_acoes = pd.read_excel("/content/Imersão Python - Tabela de ações.xlsx", sheet_name="Total_de_acoes")
df_total_de_acoes
# Out:
#                       Código  Qtde. Teórica
# 0                      RRRP3   2.356656e+08
# 1                      ALOS3   5.326166e+08
# 2                      ALPA4   1.767340e+08
# 3                      ABEV3   4.394246e+09
# 4                      ARZZ3   6.230589e+07
# ..                       ...            ...
# 84                     VBBR3   1.114413e+09
# 85                     WEGE3   1.481593e+09
# 86                     YDUQ3   2.893479e+08
# 87  Quantidade Teórica Total   9.637210e+10
# 88                   Redutor   1.704785e+07
#
# [89 rows x 2 columns]

# %%
df_ticker = pd.read_excel("/content/Imersão Python - Tabela de ações.xlsx", sheet_name="Ticker")
df_ticker
# Out:
#     Ticker            Nome
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %%
df_gemini = pd.read_excel("/content/Imersão Python - Tabela de ações.xlsx", sheet_name="Gemini")
df_gemini
# Out:
#    Nome da Empresa          Segmento  Idade (anos)
# 0         Usiminas        Siderurgia            66
# 1    CSN Mineração         Mineração            34
# 2        Petrobras    Petróleo e Gás            70
# 3           Suzano  Papel e Celulose            93
# 4     CPFL Energia           Energia           111
# ..             ...               ...           ...
# 69          Natura        Cosméticos            54
# 70           Assaí        Atacadista            38
# 71              B3  Bolsa de Valores            15
# 72          Hypera      Farmacêutica            56
# 73    São Martinho   Açúcar e Álcool            90
#
# [74 rows x 3 columns]

# %%
df_principal = df_principal[['Ativo','Data','Último (R$)','Var. Dia (%)']].copy()
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)
# 0   USIM5 2024-01-26         9.50          5.20
# 1   CMIN3 2024-01-26         6.82          2.40
# 2   PETR3 2024-01-26        41.96          2.19
# 3   SUZB3 2024-01-26        52.91          2.04
# 4   CPFE3 2024-01-26        37.10          2.03
# ..    ...        ...          ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45
# 77  BHIA3 2024-01-26         8.70         -2.46
# 78  RENT3 2024-01-26        56.24         -3.63
# 79  CVCB3 2024-01-26         3.07         -4.36
# 80  GOLL4 2024-01-26         5.92         -8.07
#
# [81 rows x 4 columns]

# %%
df_principal = df_principal.rename(columns={'Último (R$)': 'Valor_final', 'Var. Dia (%)':'Var_dia_pct' }).copy()
df_principal
# Out:
#     Ativo       Data  Valor_final  Var_dia_pct
# 0   USIM5 2024-01-26         9.50         5.20
# 1   CMIN3 2024-01-26         6.82         2.40
# 2   PETR3 2024-01-26        41.96         2.19
# 3   SUZB3 2024-01-26        52.91         2.04
# 4   CPFE3 2024-01-26        37.10         2.03
# ..    ...        ...          ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45
# 77  BHIA3 2024-01-26         8.70        -2.46
# 78  RENT3 2024-01-26        56.24        -3.63
# 79  CVCB3 2024-01-26         3.07        -4.36
# 80  GOLL4 2024-01-26         5.92        -8.07
#
# [81 rows x 4 columns]

# %%
df_principal['Var_pct'] = df_principal['Var_dia_pct']/100
df_principal['Valor_inicial'] = df_principal['Valor_final']/ (df_principal['Var_pct']+1)
df_principal
# Out:
#     Ativo       Data  Valor_final  Var_dia_pct  Var_pct  Valor_inicial
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
# [81 rows x 6 columns]

# %%
df_principal = df_principal.merge(df_total_de_acoes, left_on='Ativo', right_on='Código', how='left')
df_principal
# Out:
#     Ativo       Data  Valor_final  Var_dia_pct  Var_pct  Valor_inicial Código  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418  USIM5
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156  CMIN3
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769  PETR3
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215  SUZB3
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854  CPFE3
# ..    ...        ...          ...          ...      ...            ...    ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985  CRFB3
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418  BHIA3
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410  RENT3
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954  CVCB3
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682  GOLL4
#
#     Qtde. Teórica
# 0    5.151174e+08
# 1    1.110559e+09
# 2    2.379878e+09
# 3    6.834528e+08
# 4    1.877325e+08
# ..            ...
# 76   5.339906e+08
# 77   9.484305e+07
# 78   8.532023e+08
# 79   5.255828e+08
# 80   1.981849e+08
#
# [81 rows x 8 columns]

# %%
df_principal= df_principal.drop(columns=['Código'])
df_principal
# Out:
#     Ativo       Data  Valor_final  Var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
#     Qtde. Teórica
# 0    5.151174e+08
# 1    1.110559e+09
# 2    2.379878e+09
# 3    6.834528e+08
# 4    1.877325e+08
# ..            ...
# 76   5.339906e+08
# 77   9.484305e+07
# 78   8.532023e+08
# 79   5.255828e+08
# 80   1.981849e+08
#
# [81 rows x 7 columns]

# %%
df_principal['Variacao_rs'] = (df_principal['Valor_final']- df_principal['Valor_inicial']) * df_principal['Qtde. Teórica']
df_principal
# Out:
#     Ativo       Data  Valor_final  Var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
#     Qtde. Teórica   Variacao_rs
# 0    5.151174e+08  2.418897e+08
# 1    1.110559e+09  1.775160e+08
# 2    2.379878e+09  2.140059e+09
# 3    6.834528e+08  7.229463e+08
# 4    1.877325e+08  1.385740e+08
# ..            ...           ...
# 76   5.339906e+08 -1.436355e+08
# 77   9.484305e+07 -2.081024e+07
# 78   8.532023e+08 -1.807433e+09
# 79   5.255828e+08 -7.355741e+07
# 80   1.981849e+08 -1.029932e+08
#
# [81 rows x 8 columns]

# %%
pd.options.display.float_format= '{:.2f}'.format

# %%
df_principal['Qtde. Teórica']= df_principal['Qtde. Teórica'].astype(int)
df_principal
# Out:
#     Ativo       Data  Valor_final  Var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica    Variacao_rs
# 0       515117391   241889725.43
# 1      1110559345   177515970.30
# 2      2379877655  2140059393.53
# 3       683452836   722946282.71
# 4       187732538   138573955.06
# ..            ...            ...
# 76      533990587  -143635530.57
# 77       94843047   -20810240.84
# 78      853202347 -1807432634.46
# 79      525582771   -73557408.06
# 80      198184909  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.rename(columns={'Qtde. Teórica': 'Qtd_teorica'}).copy()
df_principal
# Out:
#     Ativo       Data  Valor_final  Var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs
# 0     515117391   241889725.43
# 1    1110559345   177515970.30
# 2    2379877655  2140059393.53
# 3     683452836   722946282.71
# 4     187732538   138573955.06
# ..          ...            ...
# 76    533990587  -143635530.57
# 77     94843047   -20810240.84
# 78    853202347 -1807432634.46
# 79    525582771   -73557408.06
# 80    198184909  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal['Resultado'] = df_principal['Variacao_rs'].apply(lambda x: 'Subiu' if x > 0 else ('Desceu' if x < 0 else 'Estável'))
df_principal
# Out:
#     Ativo       Data  Valor_final  Var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs Resultado
# 0     515117391   241889725.43     Subiu
# 1    1110559345   177515970.30     Subiu
# 2    2379877655  2140059393.53     Subiu
# 3     683452836   722946282.71     Subiu
# 4     187732538   138573955.06     Subiu
# ..          ...            ...       ...
# 76    533990587  -143635530.57    Desceu
# 77     94843047   -20810240.84    Desceu
# 78    853202347 -1807432634.46    Desceu
# 79    525582771   -73557408.06    Desceu
# 80    198184909  -102993202.62    Desceu
#
# [81 rows x 9 columns]

# %%
df_principal = df_principal.merge(df_ticker, left_on='Ativo', right_on='Ticker', how='left')
df_principal= df_principal.drop(columns=['Ticker'])
df_principal
# Out:
#     Ativo       Data  Valor_final  Var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs Resultado              Nome
# 0     515117391   241889725.43     Subiu          Usiminas
# 1    1110559345   177515970.30     Subiu     CSN Mineração
# 2    2379877655  2140059393.53     Subiu         Petrobras
# 3     683452836   722946282.71     Subiu            Suzano
# 4     187732538   138573955.06     Subiu      CPFL Energia
# ..          ...            ...       ...               ...
# 76    533990587  -143635530.57    Desceu  Carrefour Brasil
# 77     94843047   -20810240.84    Desceu       Casas Bahia
# 78    853202347 -1807432634.46    Desceu          Localiza
# 79    525582771   -73557408.06    Desceu               CVC
# 80    198184909  -102993202.62    Desceu               GOL
#
# [81 rows x 10 columns]

# %%
df_principal = df_principal.merge(df_gemini, left_on='Nome', right_on='Nome da Empresa', how='left')
df_principal= df_principal.drop(columns=['Nome da Empresa'])
df_principal
# Out:
#     Ativo       Data  Valor_final  Var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 4   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# ..    ...        ...          ...          ...      ...            ...
# 82  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 83  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 84  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 85  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 86  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs Resultado              Nome          Segmento  \
# 0     515117391   241889725.43     Subiu          Usiminas        Siderurgia
# 1    1110559345   177515970.30     Subiu     CSN Mineração         Mineração
# 2    2379877655  2140059393.53     Subiu         Petrobras    Petróleo e Gás
# 3    2379877655  2140059393.53     Subiu         Petrobras    Petróleo e Gás
# 4     683452836   722946282.71     Subiu            Suzano  Papel e Celulose
# ..          ...            ...       ...               ...               ...
# 82    533990587  -143635530.57    Desceu  Carrefour Brasil               NaN
# 83     94843047   -20810240.84    Desceu       Casas Bahia               NaN
# 84    853202347 -1807432634.46    Desceu          Localiza               NaN
# 85    525582771   -73557408.06    Desceu               CVC               NaN
# 86    198184909  -102993202.62    Desceu               GOL               NaN
#
#     Idade (anos)
# 0          66.00
# 1          34.00
# 2          70.00
# 3          70.00
# 4          93.00
# ..           ...
# 82           NaN
# 83           NaN
# 84           NaN
# 85           NaN
# 86           NaN
#
# [87 rows x 12 columns]

# %%
df_principal = df_principal.rename(columns={'Idade (anos)': 'Idade_anos'}).copy()
df_principal
# Out:
#     Ativo       Data  Valor_final  Var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 4   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# ..    ...        ...          ...          ...      ...            ...
# 82  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 83  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 84  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 85  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 86  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs Resultado              Nome          Segmento  \
# 0     515117391   241889725.43     Subiu          Usiminas        Siderurgia
# 1    1110559345   177515970.30     Subiu     CSN Mineração         Mineração
# 2    2379877655  2140059393.53     Subiu         Petrobras    Petróleo e Gás
# 3    2379877655  2140059393.53     Subiu         Petrobras    Petróleo e Gás
# 4     683452836   722946282.71     Subiu            Suzano  Papel e Celulose
# ..          ...            ...       ...               ...               ...
# 82    533990587  -143635530.57    Desceu  Carrefour Brasil               NaN
# 83     94843047   -20810240.84    Desceu       Casas Bahia               NaN
# 84    853202347 -1807432634.46    Desceu          Localiza               NaN
# 85    525582771   -73557408.06    Desceu               CVC               NaN
# 86    198184909  -102993202.62    Desceu               GOL               NaN
#
#     Idade_anos
# 0        66.00
# 1        34.00
# 2        70.00
# 3        70.00
# 4        93.00
# ..         ...
# 82         NaN
# 83         NaN
# 84         NaN
# 85         NaN
# 86         NaN
#
# [87 rows x 12 columns]

# %%
df_principal['Cat_idade'] = df_principal['Idade_anos'].apply(lambda x: 'Mais de 100 anos' if x > 100 else ('Menos de 50 anos' if x < 50 else 'Entre 50 e 100 anos'))
df_principal
# Out:
#     Ativo       Data  Valor_final  Var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 4   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# ..    ...        ...          ...          ...      ...            ...
# 82  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 83  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 84  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 85  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 86  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs Resultado              Nome          Segmento  \
# 0     515117391   241889725.43     Subiu          Usiminas        Siderurgia
# 1    1110559345   177515970.30     Subiu     CSN Mineração         Mineração
# 2    2379877655  2140059393.53     Subiu         Petrobras    Petróleo e Gás
# 3    2379877655  2140059393.53     Subiu         Petrobras    Petróleo e Gás
# 4     683452836   722946282.71     Subiu            Suzano  Papel e Celulose
# ..          ...            ...       ...               ...               ...
# 82    533990587  -143635530.57    Desceu  Carrefour Brasil               NaN
# 83     94843047   -20810240.84    Desceu       Casas Bahia               NaN
# 84    853202347 -1807432634.46    Desceu          Localiza               NaN
# 85    525582771   -73557408.06    Desceu               CVC               NaN
# 86    198184909  -102993202.62    Desceu               GOL               NaN
#
#     Idade_anos            Cat_idade
# 0        66.00  Entre 50 e 100 anos
# 1        34.00     Menos de 50 anos
# 2        70.00  Entre 50 e 100 anos
# 3        70.00  Entre 50 e 100 anos
# 4        93.00  Entre 50 e 100 anos
# ..         ...                  ...
# 82         NaN  Entre 50 e 100 anos
# 83         NaN  Entre 50 e 100 anos
# 84         NaN  Entre 50 e 100 anos
# 85         NaN  Entre 50 e 100 anos
# 86         NaN  Entre 50 e 100 anos
#
# [87 rows x 13 columns]

# %%
# Maior valor
maior_valor = df_principal['Variacao_rs'].max()

# Menor valor
menor_valor = df_principal['Variacao_rs'].min()

# Média
media = df_principal['Variacao_rs'].mean()

# Média de quem subiu
media_subiu = df_principal[df_principal['Resultado'] == 'Subiu']['Variacao_rs'].mean()

# Média de quem desceu
media_desceu = df_principal[df_principal['Resultado'] == 'Desceu']['Variacao_rs'].mean()

print("Maior:", maior_valor)
print("Menor:", menor_valor)
print("Média:", media)
print("Média de quem subiu:", media_subiu)
print("Média de quem desceu:", media_desceu)
# Out:
# Maior: 4762926995.24809
# Menor: -1807432634.4595425
# Média: 218008898.3260007
# Média de quem subiu: 538720638.3614079
# Média de quem desceu: -186265310.45906794

# %%
df_principal_subiu = df_principal[df_principal['Resultado'] == 'Subiu']
df_principal_subiu
# Out:
#     Ativo       Data  Valor_final  Var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 4   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 5   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# 6   PRIO3 2024-01-26        45.69         1.98     0.02          44.80
# 7   PETR4 2024-01-26        39.96         1.73     0.02          39.28
# 8   PETR4 2024-01-26        39.96         1.73     0.02          39.28
# 9   VALE3 2024-01-26        69.50         1.66     0.02          68.37
# 10  MULT3 2024-01-26        28.19         1.58     0.02          27.75
# 11  ITUB4 2024-01-26        32.81         1.48     0.01          32.33
# 12  RDOR3 2024-01-26        27.56         1.43     0.01          27.17
# 13  BRKM5 2024-01-26        18.55         1.42     0.01          18.29
# 14  AZUL4 2024-01-26        14.27         1.42     0.01          14.07
# 15  RRRP3 2024-01-26        28.75         1.41     0.01          28.35
# 16  EQTL3 2024-01-26        35.32         1.34     0.01          34.85
# 17  CSNA3 2024-01-26        18.16         1.33     0.01          17.92
# 18  YDUQ3 2024-01-26        19.77         1.28     0.01          19.52
# 19  UGPA3 2024-01-26        28.31         1.28     0.01          27.95
# 20  MRVE3 2024-01-26         8.08         1.25     0.01           7.98
# 21  ARZZ3 2024-01-26        57.91         1.15     0.01          57.25
# 22  BBDC4 2024-01-26        15.52         1.04     0.01          15.36
# 23  BBDC4 2024-01-26        15.52         1.04     0.01          15.36
# 24  BEEF3 2024-01-26         7.19         0.98     0.01           7.12
# 25  PCAR3 2024-01-26         4.14         0.97     0.01           4.10
# 26  BRFS3 2024-01-26        14.61         0.96     0.01          14.47
# 27  VIVT3 2024-01-26        51.20         0.88     0.01          50.75
# 28  RAIL3 2024-01-26        22.64         0.84     0.01          22.45
# 29  CIEL3 2024-01-26         4.90         0.82     0.01           4.86
# 30  DXCO3 2024-01-26         7.81         0.77     0.01           7.75
# 31  TIMS3 2024-01-26        17.52         0.74     0.01          17.39
# 32  BRAP4 2024-01-26        23.22         0.73     0.01          23.05
# 33  LWSA3 2024-01-26         5.55         0.72     0.01           5.51
# 34  RECV3 2024-01-26        23.83         0.71     0.01          23.66
# 35  ITSA4 2024-01-26        10.01         0.70     0.01           9.94
# 36  BBAS3 2024-01-26        56.97         0.68     0.01          56.59
# 37  RADL3 2024-01-26        26.16         0.61     0.01          26.00
# 38  GOAU4 2024-01-26        10.08         0.59     0.01          10.02
# 39  CSAN3 2024-01-26        18.57         0.59     0.01          18.46
# 40  JBSS3 2024-01-26        24.34         0.57     0.01          24.20
# 41  MGLU3 2024-01-26         2.08         0.48     0.00           2.07
# 42  BBDC3 2024-01-26        13.75         0.36     0.00          13.70
# 43  BBDC3 2024-01-26        13.75         0.36     0.00          13.70
# 44  GGBR4 2024-01-26        21.84         0.27     0.00          21.78
# 45  RAIZ4 2024-01-26         3.74         0.26     0.00           3.73
# 46  CPLE6 2024-01-26        10.07         0.19     0.00          10.05
# 47  VAMO3 2024-01-26         8.18         0.12     0.00           8.17
#
#     Qtd_teorica   Variacao_rs Resultado                  Nome  \
# 0     515117391  241889725.43     Subiu              Usiminas
# 1    1110559345  177515970.30     Subiu         CSN Mineração
# 2    2379877655 2140059393.53     Subiu             Petrobras
# 3    2379877655 2140059393.53     Subiu             Petrobras
# 4     683452836  722946282.71     Subiu                Suzano
# 5     187732538  138573955.06     Subiu          CPFL Energia
# 6     800010734  709687498.18     Subiu              PetroRio
# 7    4566445852 3103136291.22     Subiu             Petrobras
# 8    4566445852 3103136291.22     Subiu             Petrobras
# 9    4196924316 4762926995.25     Subiu                  Vale
# 10    268505432  117732680.08     Subiu             Multiplan
# 11   4801593832 2297591984.33     Subiu         Itaú Unibanco
# 12   1168230366  453917907.01     Subiu             Rede D'Or
# 13    265877867   69054317.64     Subiu               Braskem
# 14    327593725   65452205.55     Subiu                  Azul
# 15    235665566   94204643.35     Subiu          3R Petroleum
# 16   1095587251  511671895.45     Subiu    Equatorial Energia
# 17    600865451  143220991.46     Subiu  Siderúrgica Nacional
# 18    289347914   72295838.99     Subiu                 YDUQS
# 19   1086411192  388705223.96     Subiu              Ultrapar
# 20    376187582   37525872.38     Subiu                   MRV
# 21     62305891   41021792.09     Subiu                Arezzo
# 22   5146576868  822148336.41     Subiu        Banco Bradesco
# 23   5146576868  822148336.41     Subiu        Banco Bradesco
# 24    261036182   18214628.10     Subiu               Minerva
# 25    159430826    6340916.22     Subiu   Grupo Pão de Açúcar
# 26   1677525446  233045769.57     Subiu                   BRF
# 27    423091712  188965307.06     Subiu                  Vivo
# 28   1218352541  229771333.63     Subiu                  Rumo
# 29   1095462329   43657683.38     Subiu                 Cielo
# 30    302768240   18068446.61     Subiu                 Dexco
# 31    807896814  103972807.37     Subiu                   TIM
# 32    251003438   42238249.54     Subiu             Bradespar
# 33    393173139   15598886.65     Subiu               Locaweb
# 34    275005663   46201006.00     Subiu        PetroRecôncavo
# 35   5372783971  373853994.88     Subiu                Itaúsa
# 36   1420949112  546752087.99     Subiu       Banco do Brasil
# 37   1275798515  202352473.74     Subiu          RaiaDrogasil
# 38    660411219   39045606.94     Subiu    Metalúrgica Gerdau
# 39   1168097881  127229653.18     Subiu                 Cosan
# 40   1134986472  156573285.43     Subiu                   JBS
# 41   2867627068   28493619.27     Subiu        Magazine Luiza
# 42   1500728902   74019610.05     Subiu        Banco Bradesco
# 43   1500728902   74019610.05     Subiu        Banco Bradesco
# 44   1118525506   65779607.10     Subiu                Gerdau
# 45   1193047233   11571106.42     Subiu                Raízen
# 46   1679335290   32069789.50     Subiu                 Copel
# 47    421383330    4131341.16     Subiu           Grupo Vamos
#
#                          Segmento  Idade_anos            Cat_idade
# 0                      Siderurgia       66.00  Entre 50 e 100 anos
# 1                       Mineração       34.00     Menos de 50 anos
# 2                  Petróleo e Gás       70.00  Entre 50 e 100 anos
# 3                  Petróleo e Gás       70.00  Entre 50 e 100 anos
# 4                Papel e Celulose       93.00  Entre 50 e 100 anos
# 5                         Energia      111.00     Mais de 100 anos
# 6                  Petróleo e Gás       12.00     Menos de 50 anos
# 7                  Petróleo e Gás       70.00  Entre 50 e 100 anos
# 8                  Petróleo e Gás       70.00  Entre 50 e 100 anos
# 9                       Mineração       74.00  Entre 50 e 100 anos
# 10               Shopping Centers       42.00     Menos de 50 anos
# 11                          Banco       24.00     Menos de 50 anos
# 12                          Saúde       25.00     Menos de 50 anos
# 13                   Petroquímica       47.00     Menos de 50 anos
# 14                        Aviação       15.00     Menos de 50 anos
# 15                 Petróleo e Gás       14.00     Menos de 50 anos
# 16                        Energia      101.00     Mais de 100 anos
# 17                     Siderurgia       79.00  Entre 50 e 100 anos
# 18                       Educação        5.00     Menos de 50 anos
# 19                   Combustíveis       97.00  Entre 50 e 100 anos
# 20               Construção Civil       44.00     Menos de 50 anos
# 21                 Varejo de Moda       46.00     Menos de 50 anos
# 22                          Banco      125.00     Mais de 100 anos
# 23                          Banco      125.00     Mais de 100 anos
# 24                    Alimentação       54.00  Entre 50 e 100 anos
# 25                         Varejo       73.00  Entre 50 e 100 anos
# 26                    Alimentação       11.00     Menos de 50 anos
# 27               Telecomunicações       25.00     Menos de 50 anos
# 28                      Logística       25.00     Menos de 50 anos
# 29                     Pagamentos       24.00     Menos de 50 anos
# 30  Distribuidora de Combustíveis       27.00     Menos de 50 anos
# 31               Telecomunicações       25.00     Menos de 50 anos
# 32                        Holding       54.00  Entre 50 e 100 anos
# 33            Hospedagem de Sites       24.00     Menos de 50 anos
# 34                 Petróleo e Gás        7.00     Menos de 50 anos
# 35                        Holding       58.00  Entre 50 e 100 anos
# 36                          Banco      213.00     Mais de 100 anos
# 37            Varejo Farmacêutico       10.00     Menos de 50 anos
# 38                     Siderurgia      125.00     Mais de 100 anos
# 39                   Combustíveis       97.00  Entre 50 e 100 anos
# 40                    Alimentação       67.00  Entre 50 e 100 anos
# 41                         Varejo       78.00  Entre 50 e 100 anos
# 42                          Banco      125.00     Mais de 100 anos
# 43                          Banco      125.00     Mais de 100 anos
# 44                     Siderurgia      125.00     Mais de 100 anos
# 45                   Combustíveis       12.00     Menos de 50 anos
# 46                        Energia       77.00  Entre 50 e 100 anos
# 47                         Varejo       32.00     Menos de 50 anos

# %%
df_analise_segmento= df_principal_subiu.groupby('Segmento')['Variacao_rs'].sum().reset_index()
df_analise_segmento
# Out:
#                          Segmento    Variacao_rs
# 0                     Alimentação   407833683.09
# 1                         Aviação    65452205.55
# 2                           Banco  4636679965.25
# 3                    Combustíveis   527505983.56
# 4                Construção Civil    37525872.38
# 5   Distribuidora de Combustíveis    18068446.61
# 6                        Educação    72295838.99
# 7                         Energia   682315640.01
# 8                         Holding   416092244.42
# 9             Hospedagem de Sites    15598886.65
# 10                      Logística   229771333.63
# 11                      Mineração  4940442965.55
# 12                     Pagamentos    43657683.38
# 13               Papel e Celulose   722946282.71
# 14                   Petroquímica    69054317.64
# 15                 Petróleo e Gás 11336484517.00
# 16                          Saúde   453917907.01
# 17               Shopping Centers   117732680.08
# 18                     Siderurgia   489935930.93
# 19               Telecomunicações   292938114.42
# 20                         Varejo    38965876.66
# 21            Varejo Farmacêutico   202352473.74
# 22                 Varejo de Moda    41021792.09

# %%
df_analise_saldo= df_principal.groupby('Resultado')['Variacao_rs'].sum().reset_index()
df_analise_saldo
# Out:
#   Resultado    Variacao_rs
# 0    Desceu -6891816486.99
# 1   Estável           0.00
# 2     Subiu 25858590641.35

# %%
fig = px.bar(df_analise_saldo, x='Resultado', y='Variacao_rs', text='Variacao_rs', title= 'Variação Reais por Resultado')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="01f2d943-5145-4830-ad5b-d723838fb77b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01f2d943-5145-4830-ad5b-d723838fb77b")) {                    Plotly.newPlot(                        "01f2d943-5145-4830-ad5b-d723838fb77b",                        [{"alignmentgroup":"True","hovertemplate":"Resultado=%{x}\u003cbr\u003eVariacao_rs=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[-6891816486.985515,0.0,25858590641.34758],"textposition":"auto","x":["Desceu","Est\u00e1vel","Subiu"],"xaxis":"x","y":[-6891816486.985515,0.0,25858590641.34758],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar" ...

# %%
df_analise_cat_idade= df_principal.groupby('Cat_idade')['Variacao_rs'].sum().reset_index()
df_analise_cat_idade
# Out:
#              Cat_idade    Variacao_rs
# 0  Entre 50 e 100 anos 12529810258.10
# 1     Mais de 100 anos  3024625342.98
# 2     Menos de 50 anos  3412338553.27

# %%
fig = px.bar(df_analise_cat_idade, x='Cat_idade', y='Variacao_rs', text='Variacao_rs', title= 'Variação Reais por Categoria de Idade')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="00e45113-047e-41f9-9ce2-c2187960cafe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00e45113-047e-41f9-9ce2-c2187960cafe")) {                    Plotly.newPlot(                        "00e45113-047e-41f9-9ce2-c2187960cafe",                        [{"alignmentgroup":"True","hovertemplate":"Cat_idade=%{x}\u003cbr\u003eVariacao_rs=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[12529810258.103882,3024625342.984559,3412338553.273623],"textposition":"auto","x":["Entre 50 e 100 anos","Mais de 100 anos","Menos de 50 anos"],"xaxis":"x","y":[12529810258.103882,3024625342.984559,3412338553.273623],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fil ...

# %%
fig = px.pie(df_analise_segmento, names='Segmento', values='Variacao_rs', title='Variação Reais por Segmento')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b82123cc-1f6d-4044-b7d1-b4309cddc15e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b82123cc-1f6d-4044-b7d1-b4309cddc15e")) {                    Plotly.newPlot(                        "b82123cc-1f6d-4044-b7d1-b4309cddc15e",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Segmento=%{label}\u003cbr\u003eVariacao_rs=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Alimenta\u00e7\u00e3o","Avia\u00e7\u00e3o","Banco","Combust\u00edveis","Constru\u00e7\u00e3o Civil","Distribuidora de Combust\u00edveis","Educa\u00e7\u00e3o","Energia","Holding","Hospedagem de Sites","Log\u00edstica","Minera\u00e7\u00e3o","Pagamentos","Papel e Celulose","Petroqu\u00edmica","Petr\u00f3leo e G\u00e1s","Sa\u00fade","Shopping Centers","Siderurgia","Telecomunica\u00e7\u00f5es","Varejo","Varejo Farmac\u00eautico","Varejo de Moda"],"legendgroup":"","name":"","showlegend":true,"values":[407833683.0924499,65452205.552800186,4636679965.247721,527505983.5552523,37525872.37728388,18068446.60998324,72295838.98616095,682315640.0120441,416092244.423763,15598886.650556229,229771333.63468358,4940442965.550434,43657683.37554085,722946282.7090385,69054317.63603853,11336484517.004236,453917907.01324,117732680.0784251,489935930.9283229,292938114.42357796,38965876.65542857,202352473.73982856,41021792.09077153],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666 ...
